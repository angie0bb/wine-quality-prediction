# %% [markdown]
# ### 2. Title Recommender
#
# - Same as the wine recommendation by variety
# - Content Based Filtering: using cosine similarity
# - Using title(name of the wine) and description(review)
# - *CountVectorizer*, *TfidfTransformer*
#     - Get a commonly used words in the reviews on the same title

# %%
# library
# Importing Libraries
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
nltk.download("stopwords")

import matplotlib.pyplot as plt
from matplotlib import rcParams
import os
import seaborn as sns

# %%
# Dataset
wines2 = pd.read_csv('datasets/winemag-data-130k-v2.csv')
wines2.sample(5)  # breifly check the data
# Out:
#         Unnamed: 0   country  \
# 121397      121397        US
# 127989      127989  Portugal
# 70728        70728  Portugal
# 54517        54517        US
# 23711        23711        US
#
#                                               description  \
# 121397  This wine has a severity of sour cherry and ye...
# 127989  A structured, finely balanced wine that has in...
# 70728   This wine is full and richly fruity. It has a ...
# 54517   This wine conveys a powerful sense of extracti...
# 23711   Fruity and slightly candied flavors make this ...
#
#                                      designation  points  price    province  \
# 121397                                       NaN      85   18.0  California
# 127989                                     Mural      87   11.0       Douro
# 70728                                       Dory      87   12.0      Lisboa
# 54517                             Huber Vineyard      90   39.0  California
# 23711   Zin Nymph Sophia Favaloro Vineyard White      87   18.0  California
#
#                    region_1       region_2     taster_name  \
# 121397     Dry Creek Valley         Sonoma  Virginie Boone
# 127989                  NaN            NaN      Roger Voss
# 70728                   NaN            NaN      Roger Voss
# 54517       Sta. Rita Hills  Central Coast   Matt Kettmann
# 23711   Contra Costa County  Central Coast      Jim Gordon
#
#        taster_twitter_handle  \
# 121397               @vboone
# 127989            @vossroger
# 70728             @vossroger
# 54517          @mattkettmann
# 23711       @gordone_cellars
#
#                                                     title           variety  \
# 121397        Haraszthy 2013 Zinfandel (Dry Creek Valley)         Zinfandel
# 127989            Quinta do Portal 2013 Mural Red (Douro)    Portuguese Red
# 70728                  Adega Mãe 2015 Dory White (Lisboa)  Portuguese White
# 54517   Pali 2014 Huber Vineyard Chardonnay (Sta. Rita...        Chardonnay
# 23711   Rock Wall 2016 Zin Nymph Sophia Favaloro Viney...         Zinfandel
#
#                   winery
# 121397         Haraszthy
# 127989  Quinta do Portal
# 70728          Adega Mãe
# 54517               Pali
# 23711          Rock Wall

# %%
title_df = wines2[["title", "variety", "points", "price", "description"]]

# Drop duplicated or NAs
title_df = title_df.drop_duplicates().dropna()
title_df.head(10)
# Out:
#                                                 title             variety  \
# 1       Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 2       Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 3   St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4   Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5   Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6    Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 7               Trimbach 2012 Gewurztraminer (Alsace)      Gewürztraminer
# 8   Heinz Eifel 2013 Shine Gewürztraminer (Rheinhe...      Gewürztraminer
# 9   Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
# 10  Kirkland Signature 2011 Mountain Cuvée Caberne...  Cabernet Sauvignon
#
#     points  price                                        description
# 1       87   15.0  This is ripe and fruity, a wine that is smooth...
# 2       87   14.0  Tart and snappy, the flavors of lime flesh and...
# 3       87   13.0  Pineapple rind, lemon pith and orange blossom ...
# 4       87   65.0  Much like the regular bottling from 2012, this...
# 5       87   15.0  Blackberry and raspberry aromas show a typical...
# 6       87   16.0  Here's a bright, informal red that opens with ...
# 7       87   24.0  This dry and restrained wine offers spice in p...
# 8       87   12.0  Savory dried thyme notes accent sunnier flavor...
# 9       87   27.0  This has great depth of flavor with its fresh ...
# 10      87   19.0  Soft, supple plum envelopes an oaky structure ...

# %%
title_df.shape
# Out:
# (111592, 5)

# %%
# number of unique varieties
len(title_df["title"].unique().tolist())
# Out:
# 110637

# %%
# Count the number of reviews per title of the wine
title_rev_num = title_df["title"].value_counts()
rev_num_df = pd.DataFrame({"title":title_rev_num.index, 'rev_num':title_rev_num.values})

# Seperate varieties which have more than one review, and only have one review
multi_rev_title = rev_num_df[(rev_num_df["rev_num"]>1)]["title"].tolist()
one_rev_title = rev_num_df[(rev_num_df["rev_num"]==1)]["title"].tolist()

# %%
# Set index
title_df = title_df.set_index("title")
title_df
# Out:
#                                                                variety  \
# title
# Quinta dos Avidagos 2011 Avidagos Red (Douro)           Portuguese Red
# Rainstorm 2013 Pinot Gris (Willamette Valley)               Pinot Gris
# St. Julian 2013 Reserve Late Harvest Riesling (...            Riesling
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...          Pinot Noir
# Tandem 2011 Ars In Vitro Tempranillo-Merlot (Na...  Tempranillo-Merlot
# ...                                                                ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...            Riesling
# Citation 2004 Pinot Noir (Oregon)                           Pinot Noir
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)      Gewürztraminer
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)               Pinot Gris
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...      Gewürztraminer
#
#                                                     points  price  \
# title
# Quinta dos Avidagos 2011 Avidagos Red (Douro)           87   15.0
# Rainstorm 2013 Pinot Gris (Willamette Valley)           87   14.0
# St. Julian 2013 Reserve Late Harvest Riesling (...      87   13.0
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...      87   65.0
# Tandem 2011 Ars In Vitro Tempranillo-Merlot (Na...      87   15.0
# ...                                                    ...    ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...      90   28.0
# Citation 2004 Pinot Noir (Oregon)                       90   75.0
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)      90   30.0
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)           90   32.0
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...      90   21.0
#
#                                                                                           description
# title
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       This is ripe and fruity, a wine that is smooth...
# Rainstorm 2013 Pinot Gris (Willamette Valley)       Tart and snappy, the flavors of lime flesh and...
# St. Julian 2013 Reserve Late Harvest Riesling (...  Pineapple rind, lemon pith and orange blossom ...
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...  Much like the regular bottling from 2012, this...
# Tandem 2011 Ars In Vitro Tempranillo-Merlot (Na...  Blackberry and raspberry aromas show a typical...
# ...                                                                                               ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...  Notes of honeysuckle and cantaloupe sweeten th...
# Citation 2004 Pinot Noir (Oregon)                   Citation is given as much as a decade of bottl...
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)  Well-drained gravel soil gives this wine its c...
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)       A dry style of Pinot Gris, this is crisp with ...
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...  Big, rich and off-dry, this is powered by inte...
#
# [111592 rows x 4 columns]

# %%
title_df.loc["Force Majeure 2014 Parabellum Red (Red Mountain)"]
# Out:
#                                                                    variety  \
# title
# Force Majeure 2014 Parabellum Red (Red Mountain)  Bordeaux-style Red Blend
# Force Majeure 2014 Parabellum Red (Red Mountain)     Rhône-style Red Blend
#
#                                                   points  price  \
# title
# Force Majeure 2014 Parabellum Red (Red Mountain)      91   55.0
# Force Majeure 2014 Parabellum Red (Red Mountain)      92   45.0
#
#                                                                                         description
# title
# Force Majeure 2014 Parabellum Red (Red Mountain)  This wine is a blend of Merlot (42%), Cabernet...
# Force Majeure 2014 Parabellum Red (Red Mountain)  This wine is 61% Syrah and 39% Mourvèdre. Appe...

# %%
# TfidfTransformer, CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer


title_df2 = pd.DataFrame(columns = ["title", "variety", "points", "price","description"])

# CountVectorizer object, using 'english' as stopwords 
cv = CountVectorizer(stop_words = "english", ngram_range=(2,2))

# TfidTransformer object
tfidf_transformer = TfidfTransformer(smooth_idf = True, use_idf = True)

for title in multi_rev_title:
    df = title_df.loc[[title]]
    
    # Word counts for the words used in the reviews of a specific  variety
    word_count = cv.fit_transform(df["description"])
    
    # Compute IDF values
    tfidf_transformer.fit(word_count)
    
    # Get top 100 common words (low IDF values) used in the reviews
    df_idf = pd.DataFrame(tfidf_transformer.idf_, index = cv.get_feature_names_out(), columns = ["idf_weights"])
    df_idf.sort_values(by = ["idf_weights"], inplace = True)
    
    # put 100 common words in a list
    common_words = df_idf.iloc[:100].index.tolist()
    
    # Convert the list to a string and create a df 
    common_words_str = ", ".join(elem for elem in common_words)
    variety_lst = df.loc[title,"variety"].tolist()
    points_lst = df.loc[title, "points"].tolist()
    price_lst = df.loc[title,"price"].tolist()
    new_row = {"title": title, "variety": variety_lst[1], "points": points_lst[1], "price": price_lst[1], "description": common_words_str}
    
    title_df2 = pd.concat([title_df2, pd.DataFrame([new_row])], ignore_index=True)

# %%
# Set index again
title_df2 = title_df2.set_index("title")
title_df2
# Out:
#                                                                   variety  \
# title
# Gloria Ferrer NV Sonoma Brut Sparkling (Sonoma ...        Sparkling Blend
# Segura Viudas NV Aria Estate Extra Dry Sparklin...        Sparkling Blend
# Segura Viudas NV Extra Dry Sparkling (Cava)               Sparkling Blend
# Bailly-Lapierre NV Brut  (Crémant de Bourgogne)                Chardonnay
# J Vineyards & Winery NV Brut Rosé Sparkling (Ru...        Sparkling Blend
# ...                                                                   ...
# Joseph Drouhin 2012 Premier Cru  (Chambolle-Mus...             Pinot Noir
# Force Majeure 2014 Parabellum Red (Red Mountain)    Rhône-style Red Blend
# Mumm Napa NV Blanc de Blancs Sparkling (Napa Va...        Sparkling Blend
# L'Antica Quercia 2007 Arió Extra Dry  (Prosecco...               Prosecco
# Mailly Grand Cru NV Délice Demi-Sec  (Champagne)          Champagne Blend
#
#                                                    points  price  \
# title
# Gloria Ferrer NV Sonoma Brut Sparkling (Sonoma ...     88   22.0
# Segura Viudas NV Aria Estate Extra Dry Sparklin...     81   14.0
# Segura Viudas NV Extra Dry Sparkling (Cava)            87   10.0
# Bailly-Lapierre NV Brut  (Crémant de Bourgogne)        91   25.0
# J Vineyards & Winery NV Brut Rosé Sparkling (Ru...     90   45.0
# ...                                                   ...    ...
# Joseph Drouhin 2012 Premier Cru  (Chambolle-Mus...     93  113.0
# Force Majeure 2014 Parabellum Red (Red Mountain)       92   45.0
# Mumm Napa NV Blanc de Blancs Sparkling (Napa Va...     84   22.0
# L'Antica Quercia 2007 Arió Extra Dry  (Prosecco...     86   18.0
# Mailly Grand Cru NV Délice Demi-Sec  (Champagne)       87   45.0
#
#                                                                                           description
# title
# Gloria Ferrer NV Sonoma Brut Sparkling (Sonoma ...  sparkling wine, pinot noir, bread dough, green...
# Segura Viudas NV Aria Estate Extra Dry Sparklin...  extra dry, sweet extra, white fruit, acidic ed...
# Segura Viudas NV Extra Dry Sparkling (Cava)         lemon lime, extra dry, dry apple, powdered sug...
# Bailly-Lapierre NV Brut  (Crémant de Bourgogne)     bottle age, pinot noir, north burgundy, blanc ...
# J Vineyards & Winery NV Brut Rosé Sparkling (Ru...  abundant white, rough scoury, rough mouth, ros...
# ...                                                                                               ...
# Joseph Drouhin 2012 Premier Cru  (Chambolle-Mus...  acidity having, packed acidity, parcels premie...
# Force Majeure 2014 Parabellum Red (Red Mountain)    35 cabernet, lead bodied, lead bold, likely in...
# Mumm Napa NV Blanc de Blancs Sparkling (Napa Va...  pinot gris, 90 chardonnay, sugary orange, spar...
# L'Antica Quercia 2007 Arió Extra Dry  (Prosecco...  2007 vintage, mineral nose, mouth grapes, nose...
# Mailly Grand Cru NV Délice Demi-Sec  (Champagne)    acidity crisp, wine ready, wine holds, touch a...
#
# [774 rows x 4 columns]

# %%
title_df2 = pd.concat([title_df2, title_df.loc[one_rev_title]])
title_df2
# Out:
#                                                                variety points  \
# title
# Gloria Ferrer NV Sonoma Brut Sparkling (Sonoma ...     Sparkling Blend     88
# Segura Viudas NV Aria Estate Extra Dry Sparklin...     Sparkling Blend     81
# Segura Viudas NV Extra Dry Sparkling (Cava)            Sparkling Blend     87
# Bailly-Lapierre NV Brut  (Crémant de Bourgogne)             Chardonnay     91
# J Vineyards & Winery NV Brut Rosé Sparkling (Ru...     Sparkling Blend     90
# ...                                                                ...    ...
# Rijk's 2009 Touch of Oak Shiraz (Tulbagh)                       Shiraz     86
# Punch 2008 Tokalon Vineyard-Eastridge Vineyard ...  Cabernet Sauvignon     86
# Protopapas 2010 Chardonnay (Pageon)                         Chardonnay     86
# Pietrafitta 2009  Vernaccia di San Gimignano                 Vernaccia     86
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...      Gewürztraminer     90
#
#                                                     price  \
# title
# Gloria Ferrer NV Sonoma Brut Sparkling (Sonoma ...   22.0
# Segura Viudas NV Aria Estate Extra Dry Sparklin...   14.0
# Segura Viudas NV Extra Dry Sparkling (Cava)          10.0
# Bailly-Lapierre NV Brut  (Crémant de Bourgogne)      25.0
# J Vineyards & Winery NV Brut Rosé Sparkling (Ru...   45.0
# ...                                                   ...
# Rijk's 2009 Touch of Oak Shiraz (Tulbagh)            40.0
# Punch 2008 Tokalon Vineyard-Eastridge Vineyard ...   75.0
# Protopapas 2010 Chardonnay (Pageon)                  17.0
# Pietrafitta 2009  Vernaccia di San Gimignano         16.0
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...   21.0
#
#                                                                                           description
# title
# Gloria Ferrer NV Sonoma Brut Sparkling (Sonoma ...  sparkling wine, pinot noir, bread dough, green...
# Segura Viudas NV Aria Estate Extra Dry Sparklin...  extra dry, sweet extra, white fruit, acidic ed...
# Segura Viudas NV Extra Dry Sparkling (Cava)         lemon lime, extra dry, dry apple, powdered sug...
# Bailly-Lapierre NV Brut  (Crémant de Bourgogne)     bottle age, pinot noir, north burgundy, blanc ...
# J Vineyards & Winery NV Brut Rosé Sparkling (Ru...  abundant white, rough scoury, rough mouth, ros...
# ...                                                                                               ...
# Rijk's 2009 Touch of Oak Shiraz (Tulbagh)           Although the label reads “Touch of Oak,” this ...
# Punch 2008 Tokalon Vineyard-Eastridge Vineyard ...  A middle-of-the-road Cabernet, with ripe black...
# Protopapas 2010 Chardonnay (Pageon)                 Aromas of pineapple, orange and lemon lead thi...
# Pietrafitta 2009  Vernaccia di San Gimignano        Making wine since 961, Pietrafitta presents a ...
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...  Big, rich and off-dry, this is powered by inte...
#
# [220500 rows x 4 columns]

# %%
# TF-IDF = TF*IDF
# It will be high if the term is unique(IDF) in the whole document and the term appeared frequently in a description(TF)
from sklearn.feature_extraction.text import TfidfVectorizer

# stopwords
tfidf = TfidfVectorizer(ngram_range=(2,2), stop_words = "english")

# Count the words in each review, calculate idf, and multiply tf by idf
tfidf_matrix = tfidf.fit_transform(title_df2["description"])

# We have converted the text into a matrix of Tfidf values
tfidf_matrix.shape
